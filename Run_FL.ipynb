# %%
# %cd FL_fundamental
# Out:
# [Errno 2] No such file or directory: 'FL_fundamental'
# /home/kisejin/Documents/My_doc/VinUni_Research/code/FL_fundamental

# %%
# !pip install -r requirements.txt

# %%
# FedAvg

# File name: Cifar10_iid_FedAvg_train_c-0_3__drop-90.h5
# IID dataset - C = 0.3 - Drop-rate = 0%
# !source run_fedavg.sh Cifar10_iid 0.3 0.0

# IID dataset - C = 0.3 - Drop-rate = 50%
# !source run_fedavg.sh Cifar10_iid 0.3 0.5

# IID dataset - C = 0.3 - Drop-rate = 90%
# !source run_fedavg.sh Cifar10_iid 0.3 0.9


# Non-IID dataset - C = 0.3 - Drop-rate = 0%
# !source run_fedavg.sh Cifar10_niid 0.3 0.0

# Non-IID dataset - C = 0.3 - Drop-rate = 50%
# !source run_fedavg.sh Cifar10_niid 0.3 0.5

# Non-IID dataset - C = 0.3 - Drop-rate = 90%
# !source run_fedavg.sh Cifar10_niid 0.3 0.9
# Out:
# Changed to: /home/kisejin/Documents/My_doc/VinUni_Research/code/FL_fundamental/PFLlib/system
# ...
# Algorithm: FedAvg
# Local batch size: 20
# Local epochs: 10
# Local learing rate: 0.05
# Local learing rate decay: True
# Local learing rate decay gamma: 0.99
# Total number of clients: 50
# Clients join in each round: 0.3
# Clients randomly join: False
# Client drop rate: 0.9
# Client select regarding time: False
# Running times: 1
# Dataset: Cifar10_niid
# Number of classes: 10
# Backbone: cnn
# Using device: cuda
# Auto break: False
# Global rounds: 200
# Cuda device id: 0
# DLG attack: False
# Total number of new clients: 0
# Fine tuning epoches on new clients: 0
# ...
#
# ============= Running time: 0th =============
# Creating server and clients ...
# FedAvgCNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
# ...

# %%
# FedProx - mu = 0.001

# IID dataset - C = 0.3 - Drop-rate = 0%
# !source run_fedprox.sh Cifar10_iid 0.3 0.0 0.001

# IID dataset - C = 0.3 - Drop-rate = 50%
# !source run_fedprox.sh Cifar10_iid 0.3 0.5 0.001

# IID dataset - C = 0.3 - Drop-rate = 90%
# !source run_fedprox.sh Cifar10_iid 0.3 0.9 0.001


# Non-IID dataset - C = 0.3 - Drop-rate = 0%
# !source run_fedprox.sh Cifar10_niid 0.3 0.0 0.001

# Non-IID dataset - C = 0.3 - Drop-rate = 50%
# !source run_fedprox.sh Cifar10_niid 0.3 0.5 0.001

# Non-IID dataset - C = 0.3 - Drop-rate = 90%
# !source run_fedprox.sh Cifar10_niid 0.3 0.9 0.001
# Out:
# Changed to: /home/kisejin/Documents/My_doc/VinUni_Research/code/FL_fundamental/PFLlib/system
# ...
# Algorithm: FedProx
# Local batch size: 20
# Local epochs: 10
# Local learing rate: 0.05
# Local learing rate decay: True
# Local learing rate decay gamma: 0.99
# Total number of clients: 50
# Clients join in each round: 0.3
# Clients randomly join: False
# Client drop rate: 0.9
# Client select regarding time: False
# Running times: 1
# Dataset: Cifar10_niid
# Number of classes: 10
# Backbone: cnn
# Using device: cuda
# Auto break: False
# Global rounds: 200
# Cuda device id: 0
# DLG attack: False
# Total number of new clients: 0
# Fine tuning epoches on new clients: 0
# ...
#
# ============= Running time: 0th =============
# Creating server and clients ...
# FedAvgCNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
# ...

# %%
# FedProx - mu = 0

# IID dataset - C = 0.3 - Drop-rate = 0%
# !source run_fedprox.sh Cifar10_iid 0.3 0.0 0.0

# IID dataset - C = 0.3 - Drop-rate = 50%
# !source run_fedprox.sh Cifar10_iid 0.3 0.5 0.0

# IID dataset - C = 0.3 - Drop-rate = 90%
# !source run_fedprox.sh Cifar10_iid 0.3 0.9 0.0


# Non-IID dataset - C = 0.3 - Drop-rate = 0%
# !source run_fedprox.sh Cifar10_niid 0.3 0.0 0.0

# Non-IID dataset - C = 0.3 - Drop-rate = 50%
# !source run_fedprox.sh Cifar10_niid 0.3 0.5 0.0

# Non-IID dataset - C = 0.3 - Drop-rate = 90%
# !source run_fedprox.sh Cifar10_niid 0.3 0.9 0.0
# Out:
# Changed to: /home/kisejin/Documents/My_doc/VinUni_Research/code/FL_fundamental/PFLlib/system
# ...
# Algorithm: FedProx
# Local batch size: 20
# Local epochs: 10
# Local learing rate: 0.05
# Local learing rate decay: True
# Local learing rate decay gamma: 0.99
# Total number of clients: 50
# Clients join in each round: 0.3
# Clients randomly join: False
# Client drop rate: 0.9
# Client select regarding time: False
# Running times: 1
# Dataset: Cifar10_niid
# Number of classes: 10
# Backbone: cnn
# Using device: cuda
# Auto break: False
# Global rounds: 200
# Cuda device id: 0
# DLG attack: False
# Total number of new clients: 0
# Fine tuning epoches on new clients: 0
# ...
#
# ============= Running time: 0th =============
# Creating server and clients ...
# FedAvgCNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
# ...

# %%
#  Find best candidate mu for FedProx

# Non-IID dataset - C = 0.3 - Drop-rate = 30% - mu = 0.001
# !source run_fedprox.sh Cifar10_niid 0.3 0.3 0.001

# Non-IID dataset - C = 0.3 - Drop-rate = 30% - mu = 0.01
# !source run_fedprox.sh Cifar10_niid 0.3 0.3 0.01

# Non-IID dataset - C = 0.3 - Drop-rate = 30% - mu = 0.1
# !source run_fedprox.sh Cifar10_niid 0.3 0.3 0.1

# Non-IID dataset - C = 0.3 - Drop-rate = 30% - mu = 1
# !source run_fedprox.sh Cifar10_niid 0.3 0.3 1
# Out:
# Changed to: /home/kisejin/Documents/My_doc/VinUni_Research/code/FL_fundamental/PFLlib/system
# ...
# Algorithm: FedProx
# Local batch size: 20
# Local epochs: 10
# Local learing rate: 0.05
# Local learing rate decay: True
# Local learing rate decay gamma: 0.99
# Total number of clients: 50
# Clients join in each round: 0.3
# Clients randomly join: False
# Client drop rate: 0.3
# Client select regarding time: False
# Running times: 1
# Dataset: Cifar10_niid
# Number of classes: 10
# Backbone: cnn
# Using device: cuda
# Auto break: False
# Global rounds: 200
# Cuda device id: 0
# DLG attack: False
# Total number of new clients: 0
# Fine tuning epoches on new clients: 0
# ...
#
# ============= Running time: 0th =============
# Creating server and clients ...
# FedAvgCNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
# ...
